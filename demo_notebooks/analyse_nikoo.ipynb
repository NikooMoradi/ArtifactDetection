# %%
import os 
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

PROJECT_ROOT = Path("/home/s2864332/MySYNGAP/MySYNGAP")
DIAGNOSE_ROOT = PROJECT_ROOT / "DiagnoseSYNGAP"
AD_ROOT = PROJECT_ROOT / "ArtifactDetection"
sys.path.insert(0, str(PROJECT_ROOT))                      
sys.path.insert(0, str(AD_ROOT))                           # for artifactdetection
sys.path.insert(0, str(DIAGNOSE_ROOT))                     # for DiagnoseSYNGAP

print("PYTHONPATH:")
for p in sys.path[:3]:
    print(" ", p)

print("Paths added:")
print(AD_ROOT)
print(DIAGNOSE_ROOT)

from ArtifactDetection.artifactdetection.analyse import Analysis
# Out:
# PYTHONPATH:
#   /home/s2864332/MySYNGAP/MySYNGAP/DiagnoseSYNGAP
#   /home/s2864332/MySYNGAP/MySYNGAP/ArtifactDetection
#   /home/s2864332/MySYNGAP/MySYNGAP
# Paths added:
# /home/s2864332/MySYNGAP/MySYNGAP/ArtifactDetection
# /home/s2864332/MySYNGAP/MySYNGAP/DiagnoseSYNGAP

# %% [markdown]
# ### This notebook analyses the power results and marks epochs as noisy or clean based on a slope threshold

# %% [markdown]
# Load power file for each animal and separate into clean and noisy epochs based on the spectral slope threshold, append the analytics dataframe which counts the number of clean and noisy epochs for each animal to create an overall analytics dataframe.

# %% [markdown]
# **To run the slope analysis, you need to input the following:**
# 1. Directory path to find power analysis output
# 2. Where to save noisy and clean dataframes
# 3. List of animals (can use the same as script from power analysis script)

# %%
directory_path = '/exports/eddie/scratch/s2864332/SYNGAP_Rat_Data/ArtifactDetectTest/power/'
save_clean_folder = '/exports/eddie/scratch/s2864332/SYNGAP_Rat_Data/ArtifactDetectTest/clean_folder/'
if not os.path.exists(save_clean_folder):
    os.makedirs(save_clean_folder)
analysis_ls = ['S7063', 'S7064', 'S7068', 'S7069', 'S7070', 'S7071', 'S7072', 'S7074', 
               'S7075', 'S7076', 'S7083', 'S7086', 'S7087', 'S7088', 'S7091', 'S7092', 
               'S7094', 'S7096', 'S7098', 'S7101']
print(len(analysis_ls))
# Out:
# 20

# %%
analytics_ls = []
analysis = Analysis(directory_path, analysis_ls)
for animal in analysis_ls:
    print(animal)
    clean_power, noise_power, analytics_df = analysis.process_animal(animal = animal, save = True, save_path = save_clean_folder)
    analytics_ls.append(analytics_df)
# Out:
# S7063
# S7064
# S7068
# S7069
# S7070
# S7071
# S7072
# S7074
# S7075
# S7076
# S7083
# S7086
# S7087
# S7088
# S7091
# S7092
# S7094
# S7096
# S7098
# S7101

# %%
analytics_summary = pd.concat(analytics_ls)
analytics_summary
# Out:
#   Animal_ID  Noisy_Epochs  Clean_Epochs
# 0     S7063          3709         30851
# 0     S7064          5234         29326
# 0     S7068          1912         15368
# 0     S7069          3392         31168
# 0     S7070          4210         30350
# 0     S7071          4524         30036
# 0     S7072          5743         28817
# 0     S7074          3248         14032
# 0     S7075          3055         14225
# 0     S7076          1674         15606
# 0     S7083          5576         28984
# 0     S7086          4082         30478
# 0     S7087          7392          9888
# 0     S7088          4250         13030
# 0     S7091          3934         30626
# 0     S7092          2236         15044
# 0     S7094          3611         13669
# 0     S7096          4978         29582
# 0     S7098          4540         30020
# 0     S7101          7657         26903

# %%
# list_animal = ['S7063', 'S7064', 'S7068', 'S7070', 'S7071', 'S7072', 'S7074', 
#                'S7076', 'S7083', 'S7088', 'S7091', 'S7092', 'S7094']
list_animal = ['S7063', 'S7064', 'S7068', 'S7069', 'S7070', 'S7071', 'S7072', 'S7074', 'S7075', 
               'S7076', 'S7083', 'S7086', 'S7087', 'S7088', 'S7091', 'S7092', 'S7094', 'S7098', 'S7101']
result = analytics_summary.loc[analytics_summary["Animal_ID"].isin(list_animal), "Clean_Epochs"].sum()
print(result)
# 438421
# Out:
# 438421

# %%
clean_ls = []
noisy_ls = []
for animal in analysis_ls:
    print(animal)
    clean_df = pd.read_pickle(save_clean_folder + f'{animal}_clean_power.pkl')
    noise_df = pd.read_pickle(save_clean_folder + f'{animal}_noise_power.pkl')
    clean_ls.append(clean_df)
    noisy_ls.append(noise_df)
# Out:
# S7063
# S7064
# S7068
# S7069
# S7070
# S7071
# S7072
# S7074
# S7075
# S7076
# S7083
# S7086
# S7087
# S7088
# S7091
# S7092
# S7094
# S7096
# S7098
# S7101

# %%
clean_concat = pd.concat(clean_ls)
noise_concat = pd.concat(noisy_ls)

# %%
analysis.plot_results(noise_concat, palette=None, hue = 'Animal_ID', ylim = [10**-2, 10**8], title = 'Before Artifact Removal',
            save_folder = '/exports/eddie/scratch/s2864332/SYNGAP_Rat_Data/ArtifactDetectTest/clean_folder', save_as = 'before_artifact_removal')
# Out:
# /home/s2864332/MySYNGAP/MySYNGAP/ArtifactDetection/artifactdetection/analyse.py:97: UserWarning:
# The palette list has fewer values (18) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=data_to_plot, x='Frequency', y='Power', hue= hue,

# %%
analysis.plot_results(clean_concat, palette=None, hue = 'Animal_ID', title = 'After Artifact Removal', 
                     save_folder = '/exports/eddie/scratch/s2864332/SYNGAP_Rat_Data/ArtifactDetectTest/clean_folder/', save_as = 'after_artifact_removal')

# %% [markdown]
# #### If you want to plot by genotype or input your own colour palette, you can change these parameters as shown below:

# %%
WT_ls = ['S7068', 'S7070', 'S7071', 'S7074', 'S7086', 'S7091', 'S7098', 'S7101', 'S7083','S7087']
GAP_ls = ['S7063', 'S7064', 'S7069', 'S7072', 'S7075', 'S7076', 'S7088', 'S7092', 'S7094', 'S7096']
wt_blue_palette = ['#001f3f', '#003366', '#0052cc','#0074D9', '#0099ff','#33aaff','#7FDBFF','#39CCCC','#3D9970', 
                   '#2ECC40', '#01FF70', '#B2D8FF', '#6699cc', "#6080A0", "#0E7EEE"]


gap_red_palette = ['#FF4136',  '#FF5733', '#FF6F61', '#FF851B', '#FF8C42','#FF9F80', '#FFDC00', '#85144b', '#B10DC9',
               '#F012BE', '#FF69B4', '#FFC0CB', '#FFB6C1']
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
wt_df = clean_concat.loc[clean_concat['Animal_ID'].isin(WT_ls)]
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
gap_df = clean_concat.loc[clean_concat['Animal_ID'].isin(GAP_ls)]
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
analysis.plot_results(wt_df, palette= wt_blue_palette[0:8], hue = 'Animal_ID', ylim = [10**-2, 10**4], title = 'Wildtypes',
            save_folder = '/exports/eddie/scratch/s2864332/SYNGAP_Rat_Data/ArtifactDetectTest/clean_folder/', save_as = 'wildtypes')
# Out:
# /home/s2864332/MySYNGAP/ArtifactDetection/artifactdetection/analyse.py:97: UserWarning:
# The palette list has fewer values (8) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=data_to_plot, x='Frequency', y='Power', hue= hue,
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
analysis.plot_results(gap_df, palette= gap_red_palette[0:10], hue = 'Animal_ID', ylim = [10**-2, 10**4], title = 'Mutants',
            save_folder = '/exports/eddie/scratch/s2864332/SYNGAP_Rat_Data/ArtifactDetectTest/clean_folder/', save_as = 'mutants')
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
